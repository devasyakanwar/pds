# %% [markdown]
# # 01 - Baseline Corpus Setup
#
# This notebook covers establishing and preprocessing the 50 clean baseline documents.

# %%
# Imports
import os
import numpy as np
import pandas as pd

print("Baseline Corpus Setup Initialized")
