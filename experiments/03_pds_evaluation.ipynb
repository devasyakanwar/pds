# %% [markdown]
# # 03 - Poison Detection System Evaluation
#
# This notebook evaluates the performance of the PDS modules individually and aggregated using evaluation metrics, confusion matrices, and ROC curves.

# %%
# Imports
import os
import numpy as np
import pandas as pd
from pds import EmbeddingDetector, PerplexityScorer, InstructionDetector, HubnessDetector, PDSAggregator

print("PDS Evaluation Initialized")
