# %% [markdown]
# # 02 - Poison Crafting
#
# This notebook covers the crafting of 20 poisoned documents containing adversarial injections and anomalies.

# %%
# Imports
import os
import numpy as np
import pandas as pd

print("Poison Crafting Initialized")
